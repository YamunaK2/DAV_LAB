# %% [markdown]
# # Experiment 10: 10: Data Visualization - Normal Curves on UCI Diabetes Dataset
#
# This notebook follows the corresponding lab manual experiment.

# %%
from exp10 import run_experiment_10
run_experiment_10()
# Out:
# Saved plot to 'normal_curves.png'
