# %% [markdown]
# # Experiment 8: 8: Multiple Regression Analysis
#
# This notebook follows the corresponding lab manual experiment.

# %%
from exp8 import run_experiment_8
run_experiment_8()
# Out:
# UCI Diabetes Dataset - Multiple Regression R2 Score: 0.9464
# Pima Indians Diabetes Dataset - Multiple Regression R2 Score: 0.7068
