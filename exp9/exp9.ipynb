# %% [markdown]
# # Experiment 9: 9: Comparison of Analysis Results Between UCI and Pima Diabetes Datasets
#
# This notebook follows the corresponding lab manual experiment.

# %%
from exp9 import run_experiment_9
run_experiment_9()
# Out:
# UCI Diabetes Dataset Univariate Summary:
#          Glucose  BloodPressure        BMI        Age
# mean  137.310000      82.900000  30.947785  52.930000
# 50%   136.000000      82.500000  31.008247  54.000000
# std    35.662474      19.356047   7.786179  17.623019
# Linear Regression R2: 0.9464
# Logistic Regression Accuracy: 60.00%
#
# Pima Indians Diabetes Dataset Univariate Summary:
#          Glucose  BloodPressure        BMI       Age
# mean  136.590000      81.900000  32.458588  50.44000
# 50%   135.500000      82.500000  32.786506  50.00000
# std    31.849423      20.657134   6.920072  16.89021
# Linear Regression R2: 0.7068
# Logistic Regression Accuracy: 50.00%
#
# Comparison completed based on the same train/test procedure and selected features.
