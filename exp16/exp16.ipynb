# %% [markdown]
# # Experiment 16: 16: Time Series Analysis
#
# This notebook follows the corresponding lab manual experiment.

# %%
from exp16 import run_experiment_16
run_experiment_16()
# Out:
#             Glucose  BloodPressure  ...  Age  Outcome
# Date                                ...
# 2024-01-01       81             97  ...   62        1
# 2024-01-02      172             50  ...   21        1
# 2024-01-03       90             84  ...   29        0
# 2024-01-04      187             94  ...   35        1
# 2024-01-05      133             94  ...   62        0
#
# [5 rows x 8 columns]
# /opt/pyvenv/lib/python3.13/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /opt/pyvenv/lib/python3.13/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /opt/pyvenv/lib/python3.13/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
# ...
