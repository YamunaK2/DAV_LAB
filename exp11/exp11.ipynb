# %% [markdown]
# # Experiment 11: 11: Hypothesis Testing - Z-Test on UCI Diabetes Dataset
#
# This notebook follows the corresponding lab manual experiment.

# %%
from exp11 import run_experiment_11
run_experiment_11()
# Out:
# Z-Statistic: 10.4620
# P-Value: 0.0000
# Reject the null hypothesis: The mean Glucose level is significantly different from 100.
