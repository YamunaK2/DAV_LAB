# %% [markdown]
# # Experiment 12: 12: Performing T-Test on Diabetes Datasets
#
# This notebook follows the corresponding lab manual experiment.

# %%
from exp12 import run_experiment_12
run_experiment_12()
# Out:
# T-test Results:
#                 T-statistic   P-value
# Glucose           0.150583  0.880460
# BloodPressure     0.353250  0.724278
# BMI              -1.450337  0.148569
