# %% [markdown]
# # Experiment 13: 13: ANOVA on Diabetes Datasets
#
# This notebook follows the corresponding lab manual experiment.

# %%
from exp13 import run_experiment_13
run_experiment_13()
# Out:
# ANOVA Results:
#                 F-statistic   P-value
# Glucose           0.022675  0.880458
# BloodPressure     0.124786  0.724277
# BMI               2.103476  0.148547
#
# Decision at alpha=0.05:
# Glucose: No significant difference
# BloodPressure: No significant difference
# BMI: No significant difference
