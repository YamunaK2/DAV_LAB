# %% [markdown]
# # Experiment 14: 14: Building and Validating Linear Models
#
# This notebook follows the corresponding lab manual experiment.

# %%
from exp14 import run_experiment_14
run_experiment_14()
# Out:
# UCI Diabetes Dataset - Linear Regression Results:
# R2 Score: 0.8642, MSE: 36.2741, MAE: 2.8310
#
# Pima Indians Diabetes Dataset - Linear Regression Results:
# R2 Score: 0.8864, MSE: 23.7033, MAE: 1.8290
